# %% [markdown]
# ## Description :
#
# **Data A2**: Retail Sales: Motor Vehicle and Parts Dealers (Concessionnaires de véhicules automobiles et de pièces)
# * **Date du début : Janvier 1972**
# * **Date de la fin : Décembre 2008**
# * **Fréquence : Mensuelle**
# * **ID : TRFVOLUSM227NFWA**

# %%
### options pour ajuster la taille des figures

# %%
options(repr.plot.width = 25, repr.plot.height = 25)

# %% [markdown]
# # Importation de données

# %%
library("readxl")
workspace = "C:/Users/Wissem/Desktop/series_temporelles/projet"
PATH_TO_DATA = paste(workspace, "A2.xls", sep = "/")
dataA2 = read_excel(path = PATH_TO_DATA)

# %%
library(xts)
observation_date = as.Date(dataA2$observation_date, format="%Y-%m-%d")
observation_value = dataA2$TRFVOLUSM227NFWA
dataA2 = xts(observation_value, observation_date, frequency = 12)
names(dataA2) = "observation_value"

# %%
dataA2 = ts(dataA2, start = c(1972, 1), end = c(2008, 12), frequency = 12)

# %%
dataA2
# Out:
#      Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct
# 1972  92465  88272 102926 103238 110945 113265 118594 119913 108072 108841
# 1973  96664  92567 107490 108120 114819 115859 121685 124426 110332 113089
# 1974  95030  86426 100736 104579 112167 113888 120890 124070 109125 112572
# 1975  98342  91303 106070 107133 116659 118388 124493 126103 111399 115250
# 1976 102460  98528 114284 117014 123278 124128 130891 131913 119431 121210
# 1977 102445 102416 119960 121513 128884 129321 136199 136337 124203 127388
# 1978 109838 107018 125035 122741 134427 138883 148209 149461 131385 132930
# 1979 114354 109650 131406 129539 132394 131192 134853 139942 127576 131619
# 1980 116462 107338 125179 125698 131269 131679 136250 138666 127482 132615
# 1981 116049 109765 127798 128465 134305 135545 141253 143464 131185 133216
# 1982 109757 107512 128182 129845 140283 142111 152200 153300 136311 138780
# 1983 119436 111828 132814 132741 143619 146738 156823 157649 139938 144044
# 1984 122529 117483 137307 141327 151046 153403 161702 164920 146074 147610
# 1985 124122 119367 144424 147635 156726 158703 166881 169437 150424 154587
# 1986 132998 123526 151183 150277 160459 162370 171114 173977 155462 159434
# 1987 139918 135996 157573 159801 167776 167826 175783 177378 164184 166836
# 1988 148879 141748 167836 166804 178042 178690 184779 184503 171072 175478
# 1989 159750 146732 174990 174320 184823 184094 190985 194172 177326 182583
# 1990 163600 153559 178771 179033 189247 189529 195470 197057 178415 182634
# 1991 157889 153351 179076 179538 191929 193467 198387 204063 183594 188445
# 1992 167652 160204 183778 186069 196725 197232 206616 204753 190908 194836
# 1993 171680 162844 187869 188737 205981 199414 209838 209634 193765 197793
# 1994 169314 166444 196190 195407 206594 207280 214778 215045 200511 202864
# 1995 193838 171053 201227 198213 212586 211370 217188 219216 203866 206745
# 1996 183465 176562 204172 205253 218676 215551 225109 229050 207604 215654
# 1997 190126 183950 211952 211290 226082 222254 236713 233496 213547 221219
# 1998 196870 187167 214222 217921 227899 228733 239944 237143 219461 228523
# 1999 193581 191485 220763 220996 230786 235970 243116 241503 224306 233631
# 2000 203442 199261 232490 227698 242501 242963 245140 247832 227899 236491
# 2001 209685 200876 232587 232513 245357 243498 250363 253274 226312 241050
# 2002 215215 208237 236070 237226 251746 247868 256392 258666 233625 245556
# 2003 218534 203677 236679 239415 253244 252145 262105 260687 237451 254048
# 2004 222450 213709 251403 250968 257235 257383 265969 262836 243515 254496
# 2005 224072 219970 253182 250860 262678 263816 267025 265323 242240 251419
# 2006 233282 220711 256623 250644 263370 263782 263421 265206 245605 257939
# 2007 233621 219232 259638 252595 267574 265374 267106 271225 245965 261423
# 2008 232920 221336 252343 252088 261466 257484 261600 260609 239607 255848
#      Nov    Dec
# 1972 100791 101040
# 1973 104381  98856
# 1974 105079 105083
# 1975 106990 107945
# 1976 112996 113030
# 1977 118486 116257
# 1978 123690 124595
# 1979 123381 123226
# 1980 123420 124798
# 1981 124804 124421
# 1982 127061 127139
# 1983 133700 129776
# 1984 137272 136095
# 1985 140872 141584
# 1986 147813 149628
# 1987 155676 155580
# 1988 162957 164798
# 1989 169735 167530
# 1990 171565 168621
# 1991 169693 172782
# 1992 177380 180999
# 1993 182322 186828
# 1994 190074 193087
# 1995 194131 193341
# 1996 199643 201462
# 1997 202422 207322
# 1998 211178 216303
# 1999 221856 221465
# 2000 222819 218390
# 2001 230511 229584
# 2002 230648 234260
# 2003 233698 238538
# 2004 239796 245029
# 2005 243056 245787
# 2006 245346 248187
# 2007 245787 240281
# 2008 236465 241742

# %%
### vérifier s'il existe des valeurs nulles

# %%
sum(is.na(dataA2))
# Out:
# [1] 0

# %% [markdown]
# # Phase 1- Analyse statistique et graphique d’une série temporelle

# %% [markdown]
# ## Représentation graphique de la série temporelle

# %%
plot(dataA2, ylab="observation_value", xlab="observation_date")
# Out:
# plot without title

# %% [markdown]
# ### A travers la représentation graphique des données à étudier (dataA2) , on remarque la présence d'une tendance croissante  et d'une saisonnalité.

# %% [markdown]
# ### Pour confirmer ce qui a été observé dans la représentation graphique de la série, on peut examiner la fonction d'autocorrélation ACF.

# %% [markdown]
# ## La fonction d'autocorrélation ACF

# %%
acf(dataA2, lag.max=150, lwd=3, plot=TRUE)
# Out:
# Plot with title "observation_value"

# %% [markdown]
# ### L’ACF a montré une lente décroissance ce qui confirme notre hypothèse de la présence d’une tendance ainsi qu’un comportement (pattern) répétitif qui nous confirme la présence d’une saisonnalité.

# %% [markdown]
# ## La décomposition additive de la série

# %% [markdown]
# ### Le choix de la la décomposition additive est justifié par le fait que l'amplitude des fluctuations saisonnières sont plus ou moins constantes autour de la tendance centrale  de la série au cours du temps.

# %%
dec.a<-decompose(dataA2,"additive")
names(dec.a)
plot(dec.a)
# Out:
# [1] "x"        "seasonal" "trend"    "random"   "figure"   "type"
# plot without title

# %% [markdown]
# # Phase 2- Ajustement de la série temporelle

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ajustement de la tendance

# %% [markdown]
# ### Le résultat de la décomposition additive de la série par rapport à la tendance nous amène à choisir un ajustement linéaire de la tendance.

# %% [markdown]
# ### Rq: on peut aller au-delà d'un ajustement linéaire et considérer un ajustement polynômial d'odre 2 ou 3 de la tendance.

# %% [markdown]
# ## Ajustement de la composante saisonnière

# %% [markdown]
# ### Une saisonnalité de période paire p=12 pourraît être réduite comme suit:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t = 1 : length(dataA2)
MC = matrix(0, length(dataA2), 6)
MS = matrix(0, length(dataA2), 6)
for (i in 1:6) MC[ ,i] = cos(2*pi*t*i/12)
for (i in 1:6) MS[ ,i] = sin(2*pi*t*i/12)

# %% [markdown]
# ### Tous les paramètres issus de l'ajustement de la tendance et de l'ajustement de la composante saisonnière seront estimés par la méthode des moindres carrés via la fonction lm dans R.

# %% [markdown]
# ## Premier modèle déterministe

# %% [markdown]
# ### Le premier modèle déterministe est une combinaison linéaire d'un ajustement linéaire de la tendance et de l'ajustement de la composante saisonnière. le modèle pourraît être réduite comme suit:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Model1 = lm(dataA2~t+MC+MS)
summary(Model1)
# Out:
# Call:
# lm(formula = dataA2 ~ t + MC + MS)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -20934.6  -4089.9    491.8   4549.1  18745.9
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.353e+04  5.929e+02 157.759  < 2e-16 ***
# t            3.803e+02  2.310e+00 164.635  < 2e-16 ***
# MC1         -1.323e+04  4.184e+02 -31.632  < 2e-16 ***
# MC2          8.283e+02  4.184e+02   1.980 0.048358 *
# MC3          3.259e+03  4.184e+02   7.790 5.07e-14 ***
# MC4          3.921e+02  4.184e+02   0.937 0.349236
# MC5          1.463e+03  4.199e+02   3.484 0.000544 ***
# MC6         -7.630e+01  3.307e+02  -0.231 0.817656
# MS1         -7.995e+03  4.186e+02 -19.102  < 2e-16 ***
# MS2         -2.217e+03  4.184e+02  -5.299 1.86e-07 ***
# MS3         -2.759e+03  4.195e+02  -6.576 1.41e-10 ***
# MS4          1.394e+03  4.193e+02   3.324 0.000965 ***
# MS5          5.637e+03  4.190e+02  13.453  < 2e-16 ***
# MS6          6.294e+14  5.326e+15   0.118 0.905981
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6234 on 430 degrees of freedom
# Multiple R-squared:  0.9854,	Adjusted R-squared:  0.9849
# F-statistic:  2229 on 13 and 430 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Deuxième modèle déterministe

# %% [markdown]
# ### Le deuxième modèle déterministe est une combinaison linéaire d'un ajustement polynômial d'odre 2 de la tendance et de l'ajustement de la composante saisonnière. le modèle pourraît être réduite comme suit:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Model2 = lm(dataA2~t+I(t^2)+MC+MS)
summary(Model2)
# Out:
# Call:
# lm(formula = dataA2 ~ t + I(t^2) + MC + MS)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -24054  -3931   1081   4169  15821
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.674e+04  8.686e+02 111.377  < 2e-16 ***
# t            3.371e+02  9.016e+00  37.391  < 2e-16 ***
# I(t^2)       9.707e-02  1.963e-02   4.946 1.09e-06 ***
# MC1         -1.324e+04  4.074e+02 -32.488  < 2e-16 ***
# MC2          8.276e+02  4.074e+02   2.031 0.042846 *
# MC3          3.260e+03  4.074e+02   8.002 1.15e-14 ***
# MC4          3.918e+02  4.074e+02   0.962 0.336795
# MC5          1.471e+03  4.089e+02   3.597 0.000359 ***
# MC6         -4.351e+01  3.221e+02  -0.135 0.892625
# MS1         -7.994e+03  4.076e+02 -19.613  < 2e-16 ***
# MS2         -2.218e+03  4.074e+02  -5.444 8.78e-08 ***
# MS3         -2.766e+03  4.086e+02  -6.770 4.25e-11 ***
# MS4          1.400e+03  4.083e+02   3.428 0.000667 ***
# MS5          5.632e+03  4.080e+02  13.803  < 2e-16 ***
# MS6          1.811e+15  5.192e+15   0.349 0.727423
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6070 on 429 degrees of freedom
# Multiple R-squared:  0.9862,	Adjusted R-squared:  0.9857
# F-statistic:  2184 on 14 and 429 DF,  p-value: < 2.2e-16

# %%
AIC(Model1)
AIC(Model2)
# Out:
# [1] 9034.883
# [1] 9012.263

# %% [markdown]
# ## Comparaison entre les deux modèles déterministes

# %% [markdown]
# ### Pour les deux modèles, tous les paramètres, à l'exception des 3 composantes MC4 et MC6, et MS6, sont significatifs en fonction de la p-valeur observée.

# %% [markdown]
# ### La valeur du coefficient R^2 du 2ème modèle (98.62%) est supérieure à celle du 1er modèle (98.54%)

# %% [markdown]
# ### La valeur du coefficient R^2 ajusté du 2ème modèle (98.57%) est supérieure à celle du 1er modèle (98.49%)

# %% [markdown]
# ### La valeur du coefficient AIC du 2ème modèle (9012.26) est inférieure à celle du 1er modèle (9034.88)

# %% [markdown]
# ### On considérera le modèle qui renvoie la plus petite valeur du critère AIC et la plus grande valeur du coefficient R^2  ajusté.

# %% [markdown]
# ### Le modèle choisi est donc le deuxième modèle deterministe

# %% [markdown]
# ## Représentation graphique du 2éme modèle déterministe ajusté à la série

# %%
plot(dataA2, xlab="observation_date", ylab="observation_value", main="Série originale et série ajustée", col="blue",lwd=2)
points(time(dataA2), fitted(Model2), lwd=2, type="l", col="red")
legend("topleft", c("Série originale","série ajustée"), inset = .02, bg = "gray90", lwd=c(2,2), col=c("blue","red"))
# Out:
# Plot with title "Série originale et série ajustée"

# %% [markdown]
# # Phase 3- Analyse et modélisation des résidus issus de l’ajustement

# %% [markdown]
# ## Représentation graphique des résidus issus de l’ajustement

# %%
residuals<-Model2$residuals

plot(time(dataA2), residuals, xlab="observation_date", ylab="residuals", main="les résidus issus de l’ajustement",lwd=2,type="l")
# Out:
# Plot with title "les résidus issus de l’ajustement"

# %% [markdown]
# ## Test si les résidus correspond à un bruit blanc ou non

# %% [markdown]
# ### Une fois qu' on a ajusté la série, la question qui se pose à ce niveau est: <br> <br> Mon ajustement est-il parfait? est-ce le mieux que je puisse faire ? ou je peux améliorer encore mon ajustement ? <br> <br> Existe-t-il un pattern dans les résidus issus de mon ajustement que je peux capter et améliorer mon modèle ? <br> <br> Quand dois-je arrêter l'ajustement de ma série ?
# ### Si les résidus  issus de l’ajustement de la série correspondent à un bruit blanc, le modèle est parfait !

# %% [markdown]
# ### Les hypothèses pour qu' une série correspond à un bruit blanc: <br> <br>La moyenne de la série est nulle<br> <br> La variance de la série est constante par rapport au temps<br> <br>Il n'y a pas de corrélation entre la série elle même et des versions retardées (lagged) de la série. (absence d'autocorrélation)

# %% [markdown]
# ### La fonction d'autocorrélation ACF pour les résidus

# %%
acf(residuals)
# Out:
# Plot with title "Series  residuals"

# %% [markdown]
# ### La fonction d'autocorrélation ACF pour les résidus indique la présence d'autocorrélation et donc la 3éme hypothèse pour que une série correspond à un bruit blanc est violée.
# ### Les résidus issus de l'ajustement de la série ne correspond pas à un bruit blanc. Et donc on peut mieux faire.

# %% [markdown]
# ## Test de stationnarité

# %% [markdown]
# ### Les hypothèses pour qu' une série soit stationnaire: <br> <br>La moyenne de la série est constante par rapport au temps<br> <br> La variance de la série est constante par rapport au temps<br> <br> La fonction d'auto corrélation est constante par rapport au temps ( pas de saisonnalité)

# %% [markdown]
# ### D'après la représentation graphique et la fonction d'autocorrélation pour les résidus on constate que la variance de la série des résidus (dispersion) est à peu prés indépendente du temps, de même absence de saisonnalité. Par contre, la moyenne de la série des résidus varie au cours du temps. et donc la 1ére hypothèse pour que une série soit stationnaire est violée. et donc la série des résidus n'est pas stationnaire.
#
# ### On peut également confirmer la non stationnarité des residus à travers le test ADF.

# %% [markdown]
# #### Test ADF (Augmented Dickey-Fuller)

# %%
library(tseries)
adf.test(residuals)
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  residuals
# Dickey-Fuller = -1.5839, Lag order = 7, p-value = 0.7536
# alternative hypothesis: stationary

# %% [markdown]
# ### La p-valeur résultante du test ADF 0.753 > 0.05 et donc l'hypothèse nulle de non stationnarité est accepté.
# ### La série des résidus issus de l'ajustement ne correspond pas à une série stationnaire.

# %% [markdown]
# ## Modélisation des résidus par le modèle ARIMA

# %% [markdown]
# ### Les modèles ARMA et ARIMA sont utilisés pour modéliser des séries temporelles stationnaires. Cependant, le modèle ARIMA pourrait être utilisé dans certains cas lorsque la série n'est pas stationnaire par rapport à la tendance uniquement (la moyenne n'est pas constante par rapport au temps): l'éliminnation de la tendance peut être fait par intégration dans le modèle ARIMA(Integrated). ce qui est bien notre cas.

# %% [markdown]
# ### Pour déterminer l'ordre p du modèle AR et de l'ordre q du modèle MA, on peut traçer l'acf et le pacf des données résiduelles.

# %% [markdown]
# ### La fonction d'autocorrélation ACF pour les résidus

# %%
acf(residuals)
# Out:
# Plot with title "Series  residuals"

# %% [markdown]
# ### La fonction d'autocorrélation Partielle PACF pour les résidus

# %%
pacf(residuals,50)
# Out:
# Plot with title "Series  residuals"

# %% [markdown]
# ### Pour avoir une idée sur l'ordre p du modèle AR, nous pouvons utiliser le PACF car le PACF mesure la corrélation directe (effet direct) d'un décalage (lag) bien déterminé sur l'observation actuelle en supprimant l'effet des périodes de temps intermédiaires. Nous voulons seulement garder les retards qui ont un effet (corrélation) significatif sur l'observation actuelle et nous débarrassons des retards non significatifs.
# ### De plus, pour l'ordre q du modèle MA, nous pouvons utiliser l'acf et l'ordre q du modèle sera le retard après lequel la corrélation devient non significative.

# %% [markdown]
# ### Nous pouvons voir qu'il est difficile de déterminer p et q à partir des tracés de l'acf et du pacf dans notre cas. Nous pouvons donc utiliser la fonction auto.arima().<br> La fonction auto.arima teste plusieurs combinaisons et renvoie les modèles testés avec leurs résidus sigma^2 et le modèle avec le sigma^2 le plus bas est sélectionné. Et nous indiquerons d=1 afin que la différenciation soit considérée implicitement.

# %%
library(forecast)
ARIMA = auto.arima(residuals, d=1, trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : 8453.27
#  ARIMA(0,1,0) with drift         : 8574.051
#  ARIMA(1,1,0) with drift         : 8493.645
#  ARIMA(0,1,1) with drift         : 8476.844
#  ARIMA(0,1,0)                    : 8572.156
#  ARIMA(1,1,2) with drift         : 8475.422
#  ARIMA(2,1,1) with drift         : 8454.797
#  ARIMA(3,1,2) with drift         : 8445.292
#  ARIMA(3,1,1) with drift         : 8451.847
#  ARIMA(4,1,2) with drift         : 8422.67
#  ARIMA(4,1,1) with drift         : 8442.711
#  ARIMA(5,1,2) with drift         : 8423.538
#  ARIMA(4,1,3) with drift         : Inf
#  ARIMA(3,1,3) with drift         : 8405.686
#  ARIMA(2,1,3) with drift         : 8449.804
#  ARIMA(3,1,4) with drift         : 8407.612
#  ARIMA(2,1,4) with drift         : 8438.14
#  ARIMA(4,1,4) with drift         : 8381.468
#  ARIMA(5,1,4) with drift         : Inf
#  ARIMA(4,1,5) with drift         : 8371.325
#  ARIMA(3,1,5) with drift         : 8408.99
#  ARIMA(5,1,5) with drift         : Inf
#  ARIMA(4,1,5)                    : 8370.768
#  ARIMA(3,1,5)                    : 8408.029
#  ARIMA(4,1,4)                    : 8380.233
#  ARIMA(5,1,5)                    : Inf
#  ARIMA(3,1,4)                    : 8406.758
#  ARIMA(5,1,4)                    : Inf
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(4,1,5)                    : Inf
#  ARIMA(4,1,5) with drift         : Inf
#  ARIMA(4,1,4)                    : Inf
#  ARIMA(4,1,4) with drift         : Inf
#  ARIMA(3,1,3) with drift         : Inf
#  ARIMA(3,1,4)                    : Inf
#  ARIMA(3,1,4) with drift         : Inf
#  ARIMA(3,1,5)                    : Inf
#  ARIMA(3,1,5) with drift         : Inf
#  ARIMA(4,1,2) with drift         : 8445.401
#
#  Best model: ARIMA(4,1,2) with drift

# %% [markdown]
# ### Le résultat de la fonction auto.arima() nous donne que le bon modèle à considérer est un ARIMA(4,1,4)

# %%
Model2.res = arima(residuals, order = c(4, 1, 4))
adf.test(Model2.res$residuals)
checkresiduals(Model2.res)
# Out:
# Warning message in adf.test(Model2.res$residuals):
# "p-value smaller than printed p-value"
# 	Augmented Dickey-Fuller Test
#
# data:  Model2.res$residuals
# Dickey-Fuller = -7.8408, Lag order = 7, p-value = 0.01
# alternative hypothesis: stationary
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(4,1,4)
# Q* = 20.254, df = 3, p-value = 0.0001504
#
# Model df: 8.   Total lags used: 11
# plot without title

# %% [markdown]
# ### Nous pouvons voir maintenant que les résidus du modèle ARIMA sont stationnaires (p-valeur = 0.01 du test ADF) et correspond à un bruit blanc.(p-valeur = 0.00015 du test Ljung-Box)
# ### Notre modèle est parfait

# %% [markdown]
# ## Combinaison du deuxième modèle déterministe avec le modèle ARIMA

# %% [markdown]
# ### Recap:
# ### Le deuxième modèle déterministe ajuste la tendance et la composante saisonnière
# ### Le modèle ARIMA modélise les résidus issus de l'ajustement du deuxième modèle déterministe

# %%
Model = auto.arima(dataA2, xreg = cbind(Model2$rs, Model2$fitted.values), seasonal = FALSE)

# %%
fitted = fitted(Model, xreg = cbind(Model2$rs, Model2$fitted.values))

# %%
fitted = ts(fitted, start = c(1972, 1), end = c(2008, 12), frequency = 12)

# %%
plot(dataA2, xlab="observation_date", ylab="observation_value", main="Série originale et série ajustée", col="blue", lwd=2)
lines(fitted, lwd=2, type="l", col="red")
legend("topleft", c("Série originale","série ajustée"), inset = .02, bg = "gray90", lwd=c(2,2), col=c("blue","red"))
# Out:
# Plot with title "Série originale et série ajustée"
